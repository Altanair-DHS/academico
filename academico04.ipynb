# %%
# comando range

# %%
letra = input("Digite 'F' para Feminino ou 'M' para Masculino: ").strip().upper()

if letra == 'F':
    print("F - Feminino")
elif letra == 'M':
    print("M - Masculino")
else:
    print("Sexo Inválido.")

# %%
# Programa que verifica se uma letra é vogal ou consoante

letra = input("Digite uma letra: ").strip().lower()

# Verifica se o usuário digitou apenas uma letra
if len(letra) != 1 or not letra.isalpha():
    print("Entrada inválida. Digite apenas uma letra.")
else:
    if letra in ['a', 'e', 'i', 'o', 'u']:
        print("A letra é uma vogal.")
    else:
        print("A letra é uma consoante.")

# %%
for i in range(5):
    print(i*2)

# %%
a = 0
for i in range(9):
    a = a + 1
print(a)

# %%
a=0
b=8
for i in range(b):
    print('parabéns')

# %%
palavra='jesus'
for i in palavra:
    print(i)

# %%
lista=[1,3,45,76,89,98 ,'jesus']
for num in lista:
    print(num)
