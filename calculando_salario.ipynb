# %%
#calculando o salario

# %%
salario = float(input("Digite o salário: "))
aumento = float(input("Digite a porcentagem: "))

novo_salario = salario + (salario * (aumento / 100))

print(f"O novo salário é de R$ {novo_salario:.2f}")
# Out:
# Digite o salário:  500
# Digite a porcentagem:  5
# O novo salário é de R$ 525.00
