# %%
#biblioteca modulos e pacotes#
#import math
#import datetime
#import datetime
#datetime.date.isoformat(datetime.date.today())
#def somaQuadrados
#pip install requests
#import requests
#import radom - usada para exercicios de sorteios 
#tuplas em python
#dicionário python -
#fução keys - informa as chaves dos dicionarios
#função values - mostra valores do dicionario.
#comando clear apaga todo dicionario

# %%
import math
math.factorial(5)

# %%
import datetime
datetime.date.today()

# %%
from datetime import date

print(date.isoformat(date.today()))

# %%
#criar funções#
#fonção def

# %%
def parabens():
 print('parabéns para voce \n que as melhores te acontecam \n toda sua vida' )

# %%
parabens()

# %%
def tem_letra_u_conta():
    frase = input('Digite uma frase que tenha a letra "u": ')
    minus = frase.lower()
    quantidade = minus.count('u')
    if quantidade > 0:
        print(f'Você utilizou a letra "u" {quantidade} vez(es)!')
    else:
        print('Infelizmente, você não usou a letra "u".')

if __name__ == "__main__":
    tem_letra_u_conta()

# %%
frase = input('Digite uma frase: ')

if 'u' in frase.lower():
    print('Você usou a letra "u"!')
else:
    print('Você não usou a letra "u".')

# %%
def tem_letra_u():
    frase = input('Digite uma frase: ')
    if 'u' in frase.lower():  # .lower() ignora se for "U" maiúsculo
        print('Você utilizou a letra "u"!')
    else:
        print('Você não utilizou a letra "u".')

tem_letra_u()

# %%
def somaQuadrados(a,b):
    
    somaQ = a**2 + b**2
    return somaQ

# %%
somaQuadrados(5,8)

# %%
pip install requests

# %%
import requests

response = requests.get('https://example.com')
print(response.text)

# %%
from tkinter import Tk
root = Tk()

# %%
root.title("Minha Primeira Aplicação Tkinter")

# %%
root.geometry("600x400+50+50")

# %%
from tkinter import Button

# %%
from tkinter import Entry
entrada_texto = Entry(root)
entrada_texto.pack()

# %%
import tkinter as tk
import sqlite3

conexao = sqlite3.connect('meuaplicativo.db')

# %%
from sympy import symbols, diff
x, y = symbols('x y')
f = x**2 + y**2
gradiente = [diff(f, var) for var in (x, y)]
print(gradiente)

# %%
from sympy import symbols, diff
x, y = symbols('x y')
f = x**2 + y**2
gradiente = [diff(f, var) for var in (x, y)]
print(gradiente)

# %%
from sympy import symbols, I
x = symbols('x')
expressao_complexa = (2 + 3*I) * (4 - 5*I)
print(expressao_complexa.expand())

# %%
from sympy import simplify, sin, cos
expressao = sin(x)**2 + cos(x)**2
expressao_simplificada = simplify(expressao)
print(expressao_simplificada)

# %%
from sympy import expand, factor
expressao = (x + 1)**2
expressao_expandida = expand(expressao)
expressao_fatorada = factor(expressao_expandida)
print(f"Expandida: {expressao_expandida}, Fatorada: {expressao_fatorada}")

# %%
pip install APScheduler

# %%
pip install APScheduler

# %%
c

# %%
lista1 = [3,4,5]

# %%
type(lista1)

# %%
lista2 = [[1,2,3],[4,5,6],[7,8,9]]

# %%
select = lista2 [0][1]

# %%
print(select)

# %%
type(select)

# %%
import random

# %%
cidades = ['fortaleza','rio de janeiro','são paulo,' 'piaui', 'Roraima',' matogrosso do sul', 'Para', 'Orizonte','Quixada']
escolhida = random.choice(cidades)

# %%
print('a cidades escolhida é!',escolhida)

# %%
a = [2,3,4]

# %%
a.append(11)

# %%
print(a)

# %%
for item in b:
    a.append(item)

# %%
print(a)

# %%
type(b)

# %%
num=8

# %%
type(num)

# %%
float(num)

# %%
x=[2,4,10,6]

# %%
type(x)

# %%
nova=[]

# %%
nova[] 
for i in x:
    nova.append(float(i))

# %% [raw]
# print(nova)

# %%
lista = [2,3,4,5]

# %%
lista[3] = 7

# %%
print(list)

# %%
print(lista)

# %%
#dicionario python#

# %%
dicionario = {'curso ':'curso python para ml','produtor': 'conteudo','valores':'acessivés'}

# %%
dicionario = {'curso': 'curso python para ml', 'produtor': 'conteudo', 'valores': 'acessíveis'}

# %%
dicionario['valores']

# %%
print(a)

# %%
dicionario['curso'] = 'R$300,00'

# %%
print(dicionario)

# %%
dicionario['pre-requisito'] ='python basico'

# %%
print(dicionario)

# %%
dicionario.keys()

# %%
dicionario.c()
