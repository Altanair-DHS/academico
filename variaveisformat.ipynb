# %%
# usando variaveis format, %s %d :.2f #

fruta='melancia'

# %%
print('suco de %s é meu preferido' %fruta)
# Out:
# suco de melancia é meu preferido

# %%
type(fruta)
# Out:
# str

# %%
print('suco de {} é o meu favorito'.format(fruta))
# Out:
# suco de melancia é o meu favorito

# %%
cor1='azul'
cor2='rosa'

# %%
print('o ceu é {0}, a flor é {1} e o meu carro é {0}'.format( cor1,cor2))
# Out:
# o ceu é azul, a flor é rosa e o meu carro é azul

# %%
conta=17/3
print(conta)
# Out:
# 5.666666666666667

# %%
print('o resultado da conta é {:.2f}'. format(conta))
# Out:
# o resultado da conta é 5.67

# %%
#lmebrete importante
#if → se algo for verdadeiro

#elif → senão se (testa outra condição)

#else → caso contrário

# %%
comida = 'cozido'

if comida == 'peixe':
    print('faz bem para a saúde')
else:
    print('peixe é o brilho da cozinha')
# Out:
# peixe é o brilho da cozinha
