# %%
#Autorização para entrar na festa"balada"

# %%
idade = int(input("Digite sua idade: "))

print(idade)
if idade >= 18:
    print("Pode entrar na balada")
else:
    print("entrada proibida, você precisa ser de maior idade para entrar ")
# Out:
# Digite sua idade:  15
# 15
# entrada proibida, você precisa ser de maior idade para entrar
