# %%
#loop while e brek
#impotalção do time e sleep

# %%
import time #precisa importa o módulo time

# %%
import time
contador = 0

while contador < 10:
    print ('ainda não deu! mas dara certo')

    if contador == 3:
        brek # imterrompe o laço quando chega em 3

   contato = contador + 1
   time.sleep(1) # pausa de 1 segundo entre as repetições
print ( 'agora foi de show')
# Out:
#   File <string>:10
#     contato = contador + 1
#                           ^
# IndentationError: unindent does not match any outer indentation level
